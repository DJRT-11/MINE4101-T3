# %%
import pandas as pd

# %%
churn_df = pd.read_json("Model Training\data\churn_future.json")
churn_df
# Out:
#      customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0    7795-CFOCW    Male              0      No         No      45
# 1    9237-HQITU  Female              0      No         No       2
# 2    9305-CDSKC  Female              0      No         No       8
# 3    1452-KIOVK    Male              0      No        Yes      22
# 4    6713-OKOMC  Female              0      No         No      10
# ..          ...     ...            ...     ...        ...     ...
# 995  7164-BPTUT    Male              0      No        Yes      57
# 996  4174-LPGTI  Female              0     Yes        Yes      41
# 997  2523-EWWZL  Female              0     Yes         No      27
# 998  0928-XUTSN  Female              0      No         No      13
# 999  1980-KXVPM  Female              1      No         No       3
#
#     PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0             No  No phone service             DSL            Yes  ...
# ...

# %%
churn_bl = churn_df.sample(frac=0.5, random_state=1)
churn_op = churn_df.loc[~churn_df.index.isin(churn_bl.index)]

# %%
print(churn_bl.shape)
print(churn_op.shape)
# Out:
# (500, 21)
# (500, 21)
